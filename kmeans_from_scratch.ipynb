# %%
import os

# 1. Initialize k centroids
# Assign each point to closest centroid
# Calculate mean distance between point and centroid for each cluster, then reassign avg to the new center


import os
import numpy
import matplotlib.pyplot as plt
import math

from sklearn.datasets import make_blobs

X, y = make_blobs(n_samples=1000, centers=3, n_features=2, random_state=0)

plt.scatter(X[:,0], X[:,1], c = y)

# %%
def get_distance(p1, p2, type = "Euclidean"):
    return math.dist(p1, p2) #copoout, will add in later

def do_k_means(k = 3):
